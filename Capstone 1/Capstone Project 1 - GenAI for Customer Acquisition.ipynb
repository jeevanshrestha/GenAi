# %% [markdown]
# ## Project: GenAI for Customer Acquisition

# %% [markdown]
# ### Load Libraries

# %%
# Load the libraries
from openai import OpenAI
import os
import base64
from IPython.display import Image, display, Markdown
import pandas as pd
from io import StringIO

# %% [markdown]
# ### OpenAI Setup

# %%
# !pip install openai -q

# %%
from google.colab import userdata
api_key = userdata.get('genai_course')

# %%
#Define the model
MODEL = "gpt-4o"

# %%
#Connect to OpenAi api
client = OpenAI(api_key=api_key)

# %% [markdown]
# ### Mounting Google Drive and Setting Up the Directory

# %% [markdown]
# In this section, we mount Google Drive to access files stored in it and specify the directory containing the PDF files we want to convert.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the directory containing the PDF files
ROOT_DIR = '/content/drive/MyDrive/GenAI/Capstone 1'

# %% [markdown]
# ## PDF to Image Converter

# %% [markdown]
# ### Installing and Importing Required Libraries

# %%
# Install PyMuPDF and Pillow libraries
# !pip install PyMuPDF Pillow
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Downloading pymupdf-1.26.1-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 44.6 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.1

# %% [markdown]
# We import the libraries required for PDF manipulation and image processing.

# %%
# Import the fitz module from PyMuPDF for PDF handling
import fitz  # PyMuPDF
# Import the Image module from Pillow for image processing
from PIL import Image
# Import os for operating system dependent functionality
import os

# %% [markdown]
# * `fitz` provides functions to read and manipulate PDF files.
# * `Image` from `PIL` allows us to create and modify images.
# * `os` helps in interacting with the operating system, such as reading files and directories.

# %% [markdown]
# ### Defining the PDF to JPG Conversion Function

# %%
def pdf_to_jpg(directory):
    # Iterate over all files in the specified directory
    for filename in os.listdir(directory):
        # Check if the file is a PDF
        if filename.endswith('.pdf'):
            # Construct the full file path
            pdf_path = os.path.join(directory, filename)
            # Open the PDF document
            pdf_document = fitz.open(pdf_path)
            # Iterate over each page in the PDF
            for page_number in range(len(pdf_document)):
                # Load the page by its index
                page = pdf_document.load_page(page_number)
                # Render the page to a pixmap (an in-memory image)
                pix = page.get_pixmap()

                # Construct the output image file path
                image_path = os.path.join(
                    directory,
                    f"{os.path.splitext(filename)[0]}_page_{page_number + 1}.jpg"
                )
                # Create an image object from the pixmap data
                img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
                # Save the image in JPG format
                img.save(image_path)

    # Print a message when all conversions are done
    print("All PDF files have been converted")

# %%
directories = [ "Regatta", "Dim Sum"]
for folder in directories:
    directory = os.path.join(ROOT_DIR,folder)
    pdf_to_jpg(directory)
# Out:
# All PDF files have been converted
# All PDF files have been converted

# %% [markdown]
# # Defining the System Prompt

# %% [markdown]
#  We define a detailed system prompt that instructs the GPT model on how to convert the menu images into a structured Excel format.

# %%
# Define the system prompt with detailed instructions
system_prompt = """
Convert the menu images to s structured excel sheet
Convert the menu image to a structured excel sheet format following the provided template and instructions.
This assistant converts restaurant or cafe menu data into a structured Excel sheet that adheres to a specific template.
The template includes categories, subcategories, item names, prices, descriptions, and more, ensuring data consistency.
This assistant helps users fill out each row correctly, following the detailed instructions provided.


Rules:
- Each row in the Excel spreadsheet represents a unique item, categorized under a category or subcategory.
- Category and Subcategory names are repeated for items under the same subcategory.
- Specific columns are left blank when not applicable, such as subcategory details for items directly under a category.
- Detailed item information including names, prices, descriptions, and more should be unique for each entry.
- The content of the uploaded menu will be appended to the current menu without deleting any of the current menu.

Columns Guide:

| Column | Name                             | Description                                       | Accepted Values                       | Example         |
|--------|----------------------------------|---------------------------------------------------|----------------------------------------|-----------------|
| A      | Category TitlePT                   | Category names in Portuguese                      | Text, 256 characters max               | Bebidas         |
| B      | Category TitleEN        | (Optional) English translations of category titles| Text, 256 characters max               | Beverages       |
| C      | Subcategory TitlePT                | (Optional) Subcategory titles in Portuguese       | Text, 256 characters max or leave blank| Sucos           |
| D      | Subcategory TitleEN     | (Optional) English translations of subcategories  | Text, 256 characters max or leave blank| Juices          |
| E      | Item NamePT                        | Item names in Portuguese                          | Text, 256 characters max               | Água Mineral    |
| F      | Item NameEN             | (Optional) English translations of item names     | Text, 256 characters max or leave blank| Mineral Water   |
| G      | Item Price                       | Price of each item                                | Text                                  | 2.50 or 2,50    |
| H      | Calories                         | (Optional) The caloric content of each item       | Numeric                               | 150             |
| I      | Portion Size                     | Portion size for each item                        | Text                                  | 500ml           |
| J      | Availability                     | (Optional) Current availability of the item       | Numeric: 1 for Yes, 0 for No          | 1               |
| K      | Item DescriptionPT   | (Optional) Description in Portuguese              | Text, 500 characters max              | Contains essential minerals |
| L      | Item DescriptionEN      | (Optional) Description in English                 | Text, 500 characters max              | Contains essential minerals |

Notes:
- If Cannot translate , Copy Protugese category, subcategory  names in English columns
- Ensure all data entered follows the specified formats to maintain the integrity of the database.
- Review the data for accuracy and consistency before submitting the Excel sheet.
"""

# %% [markdown]
# This prompt provides the model with comprehensive instructions on how to process the menu images and the exact format expected for the Excel output. It includes an overview, column descriptions, and examples to ensure consistency and accuracy in the data extraction process.

# %% [markdown]
# We change the current working directory to the specified directory containing the menu images.
#
# This step ensures that all file operations are performed in the correct directory, allowing the script to access the menu images and save the Excel file in the desired location.

# %%
# Change the current working directory to the image directory

os.chdir(ROOT_DIR)
IMAGE_DIR = os.path.join(ROOT_DIR,'Dim Sum')

def encode_image(image_path):
    # Open the image file in binary mode and encode it in Base64
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# Process imaged in the directory
image_files = sorted([f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
image_files
test =image_files[0]

# %% [markdown]
# Encoding images in Base64 allows us to include image data directly in our API requests without relying on external URLs.
#
# This code scans the directory for files ending with `.png`, `.jpg`, or `.jpeg`, ensuring we only process image files relevant to our task.

# %% [markdown]
# We prompt the user to input a name for the new Excel file where the extracted data will be saved.
#
# We loop through each image file, encode it, send it to the OpenAI API for processing, and parse the response to populate our DataFrame.

# %%
#Retrieve and encode the image

image_path = os.path.join(IMAGE_DIR,test)
image_data = encode_image(image_path)

# %%
# Use GPT-4o to analyze and conver the image

user_content = [
    {"type":"text", "text":"Convert this menu image to a structured Excel Sheet Format."},
    {"type":"image_url", "image_url":{'url':f'data:image/png;base64,{image_data}'}}
]


response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content":user_content}
    ],
    temperature=0
)

# %%
print(response.choices[0].message.content.split('\n'))
for row in response.choices[0].message.content.split('\n'):
  print(row)
# Out:
# ["Here's the structured Excel sheet format based on the menu image:", '', '| Category TitlePT | Category TitleEN | Subcategory TitlePT | Subcategory TitleEN | Item NamePT                  | Item NameEN                  | Item Price | Calories | Portion Size | Availability | Item DescriptionPT                                      | Item DescriptionEN                                      |', '|------------------|------------------|---------------------|---------------------|------------------------------|------------------------------|------------|----------|--------------|--------------|--------------------------------------------------------|--------------------------------------------------------|', '| SOPAS            | Soups            |                     |                     | Sopa Won Ton                 | Won Ton Soup                 | 3,95       |          | 1 unid       |              | Paksoy, Porco e Camarão                                 | Paksoy, Pork & Shrimp                                   |', '| SOPAS            | Soups            |                     |                     | Sopa Vegetariana             | Vegetarian Soup              | 3,95       |          | 1 unid       |              | Paksoy, Bambu, Cogumelo e Verduras                      | Paksoy, Bamboo, Mushroom & Vegetables                   |', '| ARROZ & VERDURAS | Rice & Vegetables|                     |                     | Arroz branco                 | White Rice                   | 1,95       |          | 1 unid       |              | Arroz ao vapor                                          | Steamed Rice                                            |', '| ARROZ & VERDURAS | Rice & Vegetables|                     |                     | Paksoy ao vapor              | Steamed Paksoy               | 2,40       |          | 1 unid       |              | Paksoy ao vapor com Coentros                            | Steamed Paksoy with Coriander                           |', '| SIAO LONG PAO    | Siao Long Pao    |                     |                     | Siao Long Pao Tradicional    | Traditional Siao Long Pao    | 4,50       |          | 3 unid       |              | Porco, Paksoy e Cogumelo Shiitake                       | Pork, Paksoy & Shiitake Mushroom                        |', '| SIAO LONG PAO    | Siao Long Pao    |                     |                     | Siao Long Pao Negro          | Black Siao Long Pao          | 4,50       |          | 3 unid       |              | Porco, Gengibre e Cebolinho                             | Pork, Ginger & Chives                                   |', '| GYOZAS           | Gyozas           |                     |                     | Gyoza Vegetais               | Vegetable Gyoza              | 4,50       |          | 3 unid       |              |                                                        |                                                        |', '| GYOZAS           | Gyozas           |                     |                     | Gyoza Camarão                | Shrimp Gyoza                 | 4,50       |          | 3 unid       |              |                                                        |                                                        |', '| GYOZAS           | Gyozas           |                     |                     | Gyoza Pato                   | Duck Gyoza                   | 4,50       |          | 3 unid       |              |                                                        |                                                        |', '| GYOZAS           | Gyozas           |                     |                     | Gyoza Galinha                | Chicken Gyoza                | 4,50       |          | 3 unid       |              |                                                        |                                                        |', '| PRATOS           | Dishes           |                     |                     | Frango BEIJING          ...
# Here's the structured Excel sheet format based on the menu image:
#
# | Category TitlePT | Category TitleEN | Subcategory TitlePT | Subcategory TitleEN | Item NamePT                  | Item NameEN                  | Item Price | Calories | Portion Size | Availability | Item DescriptionPT                                      | Item DescriptionEN                                      |
# |------------------|------------------|---------------------|---------------------|------------------------------|------------------------------|------------|----------|--------------|--------------|--------------------------------------------------------|--------------------------------------------------------|
# | SOPAS            | Soups            |                     |                     | Sopa Won Ton                 | Won Ton Soup                 | 3,95       |          | 1 unid       |              | Paksoy, Porco e Camarão                                 | Paksoy, Pork & Shrimp                                   |
# | SOPAS            | Soups            |                     |                     | Sopa Vegetariana             | Vegetarian Soup              | 3,95       |          | 1 unid       |              | Paksoy, Bambu, Cogumelo e Verduras                      | Paksoy, Bamboo, Mushroom & Vegetables                   |
# | ARROZ & VERDURAS | Rice & Vegetables|                     |                     | Arroz branco                 | White Rice                   | 1,95       |          | 1 unid       |              | Arroz ao vapor                                          | Steamed Rice                                            |
# | ARROZ & VERDURAS | Rice & Vegetables|                     |                     | Paksoy ao vapor              | Steamed Paksoy               | 2,40       |          | 1 unid       |              | Paksoy ao vapor com Coentros                            | Steamed Paksoy with Coriander                           |
# | SIAO LONG PAO    | Siao Long Pao    |                     |                     | Siao Long Pao Tradicional    | Traditional Siao Long Pao    | 4,50       |          | 3 unid       |              | Porco, Paksoy e Cogumelo Shiitake                       | Pork, Paksoy & Shiitake Mushroom                        |
# | SIAO LONG PAO    | Siao Long Pao    |                     |                     | Siao Long Pao Negro          | Black Siao Long Pao          | 4,50       |          | 3 unid       |              | Porco, Gengibre e Cebolinho                             | Pork, Ginger & Chives                                   |
# | GYOZAS           | Gyozas           |                     |                     | Gyoza Vegetais               | Vegetable Gyoza              | 4,50       |          | 3 unid       |              |                                                        |                                                        |
# | GYOZAS           | Gyozas           |                     |                     | Gyoza Camarão                | Shrimp Gyoza                 | 4,50       |          | 3 unid       |              |                                                        |                                                        |
# | GYOZAS           | Gyozas           |                     |                     | Gyoza Pato                   | Duck Gyoza                   | 4,50       |          | 3 unid       |              |                                                        |                                                        |
# | GYOZAS           | Gyozas           |                     |                     | Gyoza Galinha                | Chicken Gyoza                | 4,50       |          | 3 unid       |              |                                                        |                                                        |
# | PRATOS           | Dishes           |                     |                     | Frango BEIJING               | Beijing Chicken              | 8,95       |          | 1 unid       |              | Frango agridoce envolto em massa crocante               | Crispy Sweet & Sour Chicken                             |
# | PRATOS           | Dishes           |                     |                     | Camarão Penghu               | Penghu Shrimp                | 9,95       |          | 1 unid       |              | Camarão agridoce envolto em massa crocante              | Crispy Sweet & Sour Shrimp                              |
#
# This table captures the menu items, their descriptions, and prices in both Portuguese and English.

# %%
df = pd.DataFrame()
# Clean and filter only relevant lines (non-separator lines)
lines = [line.strip('|').strip() for line in response.choices[0].message.content.split('\n') if line.startswith('|') and not line.startswith('|-')]

# Join cleaned lines into CSV-style content
cleaned_data = "\n".join(lines)

# Parse into DataFrame
df = pd.read_csv(StringIO(cleaned_data), sep="|")

# Strip whitespace
df.columns = df.columns.str.strip()
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df
# Out:
#     Category TitlePT   Category TitleEN Subcategory TitlePT  \
# 0              SOPAS              Soups
# 1              SOPAS              Soups
# 2   ARROZ & VERDURAS  Rice & Vegetables
# 3   ARROZ & VERDURAS  Rice & Vegetables
# 4      SIAO LONG PAO      Siao Long Pao
# 5      SIAO LONG PAO      Siao Long Pao
# 6             GYOZAS             Gyozas
# 7             GYOZAS             Gyozas
# 8             GYOZAS             Gyozas
# 9             GYOZAS             Gyozas
# 10            PRATOS             Dishes
# 11            PRATOS             Dishes
#
#    Subcategory TitleEN                Item NamePT                Item NameEN  \
# 0                                    Sopa Won Ton               Won Ton Soup
# 1                                Sopa Vegetariana            Vegetarian Soup
# 2                                    Arroz branco                 White Rice
# 3                                 Paksoy ao vapor             Steamed Paksoy
# 4                       Siao Long Pao Tradicional  Traditional Siao Long Pao
# 5                             Siao Long Pao Negro        Black Siao Long Pao
# 6                                  Gyoza Vegetais            Vegetable Gyoza
# 7                                   Gyoza Camarão               Shrimp Gyoza
# 8                                      Gyoza Pato                 Duck Gyoza
# 9                                   Gyoza Galinha              Chicken Gyoza
# 10                                 Frango BEIJING            Beijing Chicken
# 11                                 Camarão Penghu              Penghu Shrimp
#
#    Item Price Calories Portion Size Availability  \
# 0        3,95                1 unid
# 1        3,95                1 unid
# 2        1,95                1 unid
# 3        2,40                1 unid
# 4        4,50                3 unid
# 5        4,50                3 unid
# 6        4,50                3 unid
# 7        4,50                3 unid
# 8        4,50                3 unid
# 9        4,50                3 unid
# 10       8,95                1 unid
# 11       9,95                1 unid
#
#                             Item DescriptionPT  \
# 0                      Paksoy, Porco e Camarão
# 1           Paksoy, Bambu, Cogumelo e Verduras
# 2                               Arroz ao vapor
# 3                 Paksoy ao vapor com Coentros
# 4            Porco, Paksoy e Cogumelo Shiitake
# 5                  Porco, Gengibre e Cebolinho
# 6
# 7
# 8
# 9
# 10   Frango agridoce envolto em massa crocante
# 11  Camarão agridoce envolto em massa crocante
#
#                        Item DescriptionEN
# 0                   Paksoy, Pork & Shrimp
# 1   Paksoy, Bamboo, Mushroom & Vegetables
# 2                            Steamed Rice
# 3           Steamed Paksoy with Coriander
# 4        Pork, Paksoy & Shiitake Mushroom
# 5                   Pork, Ginger & Chives
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10            Crispy Sweet & Sour Chicken
# 11             Crispy Sweet & Sour Shrimp

# %% [markdown]
# #### Loop Through All the Images

# %%
df = pd.DataFrame()
header_added = False

for image_file in image_files:
    image_path = os.path.join(IMAGE_DIR, image_file)
    image_data = encode_image(image_path)

    user_content = [
        {"type": "text", "text": "Convert this menu image to a structured Excel Sheet Format."},
        {"type": "image_url", "image_url": {'url': f'data:image/png;base64,{image_data}'}}
    ]

    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_content}
        ],
        temperature=0
    )

    # Parse the markdown table into CSV-style content
    lines = [
        line.strip('|').strip()
        for line in response.choices[0].message.content.split('\n')
        if line.startswith('|') and not line.startswith('|-')
    ]
    cleaned_data = "\n".join(lines)

    # Convert to DataFrame
    df_new = pd.read_csv(StringIO(cleaned_data), sep='|')

    # Clean columns and values
    df_new.columns = df_new.columns.str.strip()
    df_new = df_new.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # Append
    if not header_added:
        df = pd.concat([df, df_new], ignore_index=True)
        header_added = True
    else:
        df = pd.concat([df, df_new.iloc[1:]], ignore_index=True)  # Skip duplicated header row

# Preview result
print(df.head())
# Out:
#    Category TitlePT   Category TitleEN Subcategory TitlePT  \
# 0             SOPAS              Soups
# 1             SOPAS              Soups
# 2  ARROZ & VERDURAS  Rice & Vegetables
# 3  ARROZ & VERDURAS  Rice & Vegetables
# 4     SIAO LONG PAO
#
#   Subcategory TitleEN                Item NamePT                Item NameEN  \
# 0                                   Sopa Won Ton               Won Ton Soup
# 1                               Sopa Vegetariana            Vegetarian Soup
# 2                                   Arroz branco                 White Rice
# 3                                Paksoy ao vapor             Steamed Paksoy
# 4                      Siao Long Pao Tradicional  Traditional Siao Long Pao
#
#   Item Price Calories Portion Size Availability  \
# 0       3,95                1 unid            1
# 1       3,95                1 unid            1
# 2       1,95                1 unid            1
# 3       2,40                1 unid            1
# 4       4,50                1 unid            1
#
#                    Item DescriptionPT                     Item DescriptionEN
# 0             Paksoy, Porco e Camarão                  Paksoy, Pork & Shrimp
# 1  Paksoy, Bambu, Cogumelo e Verduras  Paksoy, Bamboo, Mushroom & Vegetables
# 2                      Arroz ao vapor                           Steamed Rice
# 3        Paksoy ao vapor com Coentros          Steamed Paksoy with Coriander
# 4   Porco, Paksoy e Cogumelo Shiitake       Pork, Paksoy & Shiitake Mushroom

# %%
df
# Out:
#     Category TitlePT   Category TitleEN Subcategory TitlePT  \
# 0              SOPAS              Soups
# 1              SOPAS              Soups
# 2   ARROZ & VERDURAS  Rice & Vegetables
# 3   ARROZ & VERDURAS  Rice & Vegetables
# 4      SIAO LONG PAO
# 5      SIAO LONG PAO
# 6             GYOZAS
# 7             GYOZAS
# 8             GYOZAS
# 9             GYOZAS
# 10            PRATOS             Dishes
# 11            PRATOS             Dishes
# 12      OS CLASSICOS       OS CLASSICOS
# 13      OS CLASSICOS       OS CLASSICOS
# 14      OS CLASSICOS       OS CLASSICOS
# 15      OS CLASSICOS       OS CLASSICOS
# 16      OS CLASSICOS       OS CLASSICOS
# 17      OS CLASSICOS       OS CLASSICOS
# 18      OS CLASSICOS       OS CLASSICOS
# 19              BAOS               BAOS
# 20              BAOS               BAOS
# 21              BAOS               BAOS
# 22              BAOS               BAOS
# 23  OS NOSSOS CREPES         OUR CREPES
# 24  OS NOSSOS CREPES         OUR CREPES
# 25  OS NOSSOS CREPES         OUR CREPES
# 26  OUTROS CROCANTES    OTHER CRUNCHIES
# 27  OUTROS CROCANTES    OTHER CRUNCHIES
# 28  OUTROS CROCANTES    OTHER CRUNCHIES
# 29  OUTROS CROCANTES    OTHER CRUNCHIES
# 30        Sobremesas           Desserts              Mochis
# 31        Sobremesas           Desserts              Mochis
# 32        Sobremesas           Desserts      Mochis Gelados
# 33        Sobremesas           Desserts      Mochis Gelados
# 34           Bebidas          Beverages          Chás Frios
# 35           Bebidas          Beverages          Chás Frios
# 36           Bebidas          Beverages        Chás Quentes
# 37           Bebidas          Beverages       Refrigerantes
# 38           Bebidas          Beverages       Refrigerantes
# 39           Bebidas          Beverages       Refrigerantes
# 40           Bebidas          Beverages       Refrigerantes
# 41           Bebidas          Beverages            Cervejas
# 42           Bebidas          Beverages            Cervejas
# 43           Bebidas          Beverages            Cervejas
# 44           Bebidas          Beverages              Vinhos
# 45           Bebidas          Beverages              Vinhos
# 46           Bebidas          Beverages              Vinhos
# 47           Bebidas          Beverages              Vinhos
# 48           Bebidas          Beverages               Águas
# 49           Bebidas          Beverages               Águas
# 50           Bebidas          Beverages               Águas
# 51           Bebidas          Beverages               Cafés
#
#    Subcategory TitleEN                              Item NamePT  \
# 0                                                  Sopa Won Ton
# 1                                              Sopa Vegetariana
# 2                                                  Arroz branco
# 3                                               Paksoy ao vapor
# 4                                     Siao Long Pao Tradicional
# 5                                           Siao Long Pao Negro
# 6                                                Gyoza Vegetais
# 7                                                 Gyoza Camarão
# 8                                                    Gyoza Pato
# 9                                                 Gyoza Galinha
# 10                                               Frango BEIJING
# 11                                               Camarão Penghu
# 12                                                      Har Kau
# 13                                            Siu Mai Hong Kong
# 14                                                Siu Mai Arroz
# 15                                                Shui Jing Kao
# 16                                               Arroz em Lótus
# 17                                            Rolinhos ao Vapor
# 18                                                 Jiaozi Verde
# 19                                               BAO de Camarão
# 20                                                 BAO de Choco
# 21                                                 BAO de Porco
# 22                                                  BAO de Tofu
# 23                                        Crepes de Pato Lacado
# 24                      Crepes de Vitela e camarão com espargos
# 25                                           Crepes de Vegetais
# 26                                         Saquinhos da Fortuna
# 27                                             Won Ton Szechuan
# 28                                               Camarão Xangai
# 29                                                    Crab Cake
# 30              Mochis                        Mochi de Amendoim
# 31              Mochis                       Mochi de Chá Verde
# 32         Iced Mochis  Mochi Gelado Amêndoa e Caramelo Salgado
# 33         Iced Mochis               Mochi Gelado Ananás e Côco
# 34           Cold Teas                   Verde Gengibre e Limão
# 35           Cold Teas                          Menta e Abacaxi
# 36            Hot Teas         Verde / Jasmin / Menta / Rooibos
# 37         Soft Drinks           Coca-Cola/Coca-Cola Zero 33 cl
# 38         Soft Drinks                     Nestea Pêssego 33 cl
# 39         Soft Drinks                              Fanta 33 cl
# 40         Soft Drinks                                 Limonada
# 41               Beers                         Heineken Pressão
# 42               Beers                 Heineken s/ álcool 25 cl
# 43               Beers                           Tsingtao 33 cl
# 44               Wines                     Lello Branco / Tinto
# 45               Wines                               Copo 20 cl
# 46               Wines                            Garrafa 75 cl
# 47               Wines                        Mateus Rosé 25 cl
# 48               Water           Lisa Carvalhelhos 25 cl s/ gás
# 49               Water            Lisa Monchique 37.5 cl s/ gás
# 50               Water                     Com Gás Pedras 25 cl
# 51              Coffee             Café Expresso / Descafeinado
#
#                            Item NameEN Item Price Calories Portion Size  \
# 0                         Won Ton Soup       3,95                1 unid
# 1                      Vegetarian Soup       3,95                1 unid
# 2                           White Rice       1,95                1 unid
# 3                       Steamed Paksoy       2,40                1 unid
# 4            Traditional Siao Long Pao       4,50                1 unid
# 5                  Black Siao Long Pao       4,50                1 unid
# 6                      Vegetable Gyoza       4,50                3 unid
# 7                         Shrimp Gyoza       4,50                3 unid
# 8                           Duck Gyoza       4,50                3 unid
# 9                        Chicken Gyoza       4,50                3 unid
# 10                     Beijing Chicken       8,95                1 unid
# 11                       Penghu Shrimp       9,95                1 unid
# 12                             Har Kau      €4,50                3 unid
# 13                   Siu Mai Hong Kong      €4,50                4 unid
# 14                       Siu Mai Arroz      €4,50                6 unid
# 15                       Shui Jing Kao      €4,50                3 unid
# 16                      Arroz em Lótus      €5,30                1 unid
# 17                   Rolinhos ao Vapor      €4,50                2 unid
# 18                        Jiaozi Verde      €4,50                3 unid
# 19                          Shrimp BAO       4,70                1 unid
# 20                      Cuttlefish BAO       4,70                1 unid
# 21                            Pork BAO       4,70                1 unid
# 22                            Tofu BAO       4,70                1 unid
# 23                         Duck Crepes       4,90                2 unid
# 24     Veal, Shrimp & Asparagus Crepes       4,90                2 unid
# 25                    Vegetable Crepes       4,90                2 unid
# 26                        Fortune Bags       4,50                3 unid
# 27                    Szechuan Won Ton       4,50                3 unid
# 28                     Shanghai Shrimp       4,50                3 unid
# 29                           Crab Cake       4,50                3 unid
# 30                        Peanut Mochi       1,70
# 31                     Green Tea Mochi       1,70
# 32  Almond & Salted Caramel Iced Mochi       2,10
# 33      Pineapple & Coconut Iced Mochi       2,10
# 34            Green Tea, Ginger, Lemon        3.0
# 35                    Mint & Pineapple        3.0
# 36     Green / Jasmin / Mint / Rooibos        2.2
# 37      Coca-Cola/Coca-Cola Zero 33 cl        2.0
# 38                  Nestea Peach 33 cl        2.0
# 39                         Fanta 33 cl        2.0
# 40                            Lemonade        2.0
# 41                      Heineken Draft        2.0
# 42        Heineken non-alcoholic 25 cl        1.9
# 43                      Tsingtao 33 cl        3.5
# 44              Lello White / Red Wine        2.5
# 45                         Glass 20 cl        2.5
# 46                        Bottle 75 cl        9.5
# 47                   Mateus Rosé 25 cl        2.5
# 48       Lisa Carvalhelhos 25 cl Still        1.6
# 49        Lisa Monchique 37.5 cl Still        1.6
# 50              Sparkling Pedras 25 cl        1.6
# 51            Espresso / Decaffeinated        1.0
#
#    Availability                          Item DescriptionPT  \
# 0             1                     Paksoy, Porco e Camarão
# 1             1          Paksoy, Bambu, Cogumelo e Verduras
# 2             1                              Arroz ao vapor
# 3             1                Paksoy ao vapor com Coentros
# 4             1           Porco, Paksoy e Cogumelo Shiitake
# 5             1                 Porco, Gengibre e Cebolinho
# 6             1
# 7             1
# 8             1
# 9             1
# 10            1   Frango agridoce envolto em massa crocante
# 11            1  Camarão agridoce envolto em massa crocante
# 12                                          Camarão e Bambu
# 13                        Gambas, Porco e Cogumelo Shiitake
# 14                                Arroz e Cogumelo Shiitake
# 15                               Bambu, Cogumelo e Verduras
# 16                       Arroz, Galinha, Camarão e Cogumelo
# 17                        Camarão, Lulas e Ervas aromáticas
# 18                               Paksoi e Cogumelo Shiitake
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26                 Galinha, Vegetais, côco e aroma de caril
# 27                          Porco, Paksoy, Soja e Piri-piri
# 28                        Camarão e Batata em molho picante
# 29                     Peixe, Caranguejo, Batata e Vegetais
# 30            1
# 31            1
# 32            1
# 33            1
# 34            1
# 35            1
# 36            1
# 37            1
# 38            1
# 39            1
# 40            1
# 41            1
# 42            1
# 43            1
# 44            1
# 45            1
# 46            1
# 47            1
# 48            1
# 49            1
# 50            1
# 51            1
#
#                             Item DescriptionEN
# 0                        Paksoy, Pork & Shrimp
# 1        Paksoy, Bamboo, Mushroom & Vegetables
# 2                                 Steamed Rice
# 3                Steamed Paksoy with Coriander
# 4             Pork, Paksoy & Shiitake Mushroom
# 5                        Pork, Ginger & Chives
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                 Crispy Sweet & Sour Chicken
# 11                  Crispy Sweet & Sour Shrimp
# 12                             Shrimp & Bamboo
# 13            Shrimp, Pork & Shiitake Mushroom
# 14                    Rice & Shiitake Mushroom
# 15               Bamboo, Mushroom & Vegetables
# 16            Rice, Chicken, Shrimp & Mushroom
# 17                       Shrimp, Squid & Herbs
# 18                  Paksoi & Shiitake Mushroom
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26  Chicken, Vegetables, coconut & curry aroma
# 27                 Pork, Paksoy, Soya & Chilli
# 28             Shrimp & Potato in Chilli sauce
# 29             Fish, Crab, Potato & Vegetables
# 30                                         NaN
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49                                         NaN
# 50                                         NaN
# 51                                         NaN

# %% [markdown]
# In this loop:
#
# * **Encoding the Image**: Each image is encoded in Base64 format using the `encode_image` function.
# * **API Request**: We send the encoded image along with the prompt to the OpenAI API using `client.chat.completions.create`.
# * **Temperature Parameter**: We set `temperature=0` to make the output deterministic, ensuring consistent formatting.
# * **Response Parsing**: The API response is expected to be in a Markdown table format. We parse each line, checking if it's a data row.
# * **Data Extraction**: We extract the columns, check if they match the expected number of DataFrame columns, and append them to the DataFrame.

# %%
# Save Data Frame to Excel Sheet
path_to_save = os.path.join(IMAGE_DIR,'','menu_data.xlsx')
df.to_excel(path_to_save, index=False)

# %% [markdown]
# After processing all images, we save the populated DataFrame to an Excel file.

# %% [markdown]
# This script demonstrates how to automate the extraction of structured data from menu images using the OpenAI GPT model.
#
# By converting menu images into a standardized Excel format, we facilitate easier data management and analysis for restaurant or cafe menus.
#
# The use of the OpenAI API for image-to-text conversion streamlines the data entry process, reducing manual effort and potential errors.
